# %%
import datetime as dt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ppk_locality = pd.read_csv('../data/ppk_locality.csv', index_col=0, low_memory=False)

sns.lineplot(data=ppk_locality, x='seasonal_year', y='ppk', hue='sellers_locality', legend=False)
# Out:
# <Axes: xlabel='seasonal_year', ylabel='ppk'>

# %% [markdown]
# ## Total Daily Catch During Fishing Seasons 2012-2022

# %%
total_daily_catch = pd.read_csv('../data/total_daily_catch.csv')
plt.figure(figsize = (16, 5))
sns.lineplot(total_daily_catch, x='seasonal_day', y='cumulative', hue='seasonal_year', palette='colorblind')
# Out:
# <Axes: xlabel='seasonal_day', ylabel='cumulative'>

# %% [markdown]
# ### Correlation Tests (Season Start, End, and Length ~ Fishing Season)

# %%
total_first_catch = pd.read_csv('../data/total_first_catch.csv')
total_first_catch.corr(method='kendall').loc['first_catch_day', 'season']
sns.lmplot(data=total_first_catch, x='season', y='first_catch_day', legend=False)

# %%
total_last_catch = pd.read_csv('../data/total_last_catch.csv')
total_last_catch.corr(method='kendall').loc['last_catch_day', 'season']
sns.lmplot(data=total_last_catch, x='season', y='last_catch_day', legend=False)

# %%
total_ice_season_length = pd.read_csv('../data/total_ice_season_length.csv')
total_ice_season_length.corr(method='kendall').loc['ice_season_length', 'season']
sns.lmplot(data=total_ice_season_length, x='season', y='ice_season_length', legend=False)

# %% [markdown]
# ### Local First Catch

# %%
local_first_catch = pd.read_csv('../data/local_first_catch.csv')

sns.scatterplot(data=local_first_catch, x='season', y='first_catch_day', hue='field_code', palette='colorblind', legend=False)

#todo
# this plot needs revision, does not run
#plt.figure(figsize = (5, 5))
#kendall_corr = local_first_catch.groupby('field_code').corr(method='kendall').unstack()['season']['first_catch_day'].dropna()
#kendall_corr.plot.hist()
#(kendall_corr > 0).value_counts()

# %% [markdown]
# ### Local Last Catch

# %%
local_last_catch = pd.read_csv('../data/local_last_catch.csv')

sns.scatterplot(data=local_last_catch, x='season', y='last_catch_day', hue='sellers_locality', palette='colorblind', legend=False)
# Out:
# <Axes: xlabel='season', ylabel='last_catch_day'>

# %%
#todo

#plt.figure(figsize = (5, 5))
#kendall_corr = local_last_catch.groupby('field_code').corr(method='kendall').unstack()['season']['last_catch_day'].dropna()
#kendall_corr.plot.hist()
#(kendall_corr < 0).value_counts()

# %% [markdown]
# ### Number of Fields Fished, 2012-2022

# %%
num_fields = pd.read_csv('../data/num_fields.csv')
sns.barplot(data=num_fields, x='season', y='n_fields')

# %% [markdown]
# ### Local Number of Fields fished, 2012-2022

# %%
local_num_fields
# Out:
#      Unnamed: 0  seasonal_year    sellers_locality  n_fields
# 0             0           2012          Innaarsuit         1
# 1             1           2012          Kullorsuaq         1
# 2             2           2012             Naajaat         1
# 3             3           2012           Niaqornat         1
# 4             4           2012            Qeqertaq         2
# ..          ...            ...                 ...       ...
# 101         101           2021          Ukkusissat         1
# 102         102           2021           Upernavik         2
# 103         103           2021  Upernavik Kujalleq         1
# 104         104           2021           Uummannaq         8
# 105         105           2022          Innaarsuit         1
#
# [106 rows x 4 columns]

# %% [markdown]
# ### Fishing Grounds

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 fishing_grounds = landings.groupby(by=['seasonal_year', 'sellers_locality', 'vessel_type', 'field_code']).seller_id.nunique().reset_index().drop(columns='seller_id')
#       2 fishing_grounds
#
# NameError: name 'landings' is not defined
